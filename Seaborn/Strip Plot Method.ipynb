# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
da=sns.load_dataset("tips")

# %%
sns.stripplot(x="day",y="total_bill",data=da)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(x="day",y="total_bill",data=da,hue="sex")
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(x="day",y="total_bill",data=da,hue="sex",palette="OrRd")
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(x="day",y="total_bill",data=da,hue="sex",palette="OrRd",linewidth=1,edgecolor='r')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(y=da["total_bill"],hue="gs")
# Out:
# <AxesSubplot:ylabel='total_bill'>
